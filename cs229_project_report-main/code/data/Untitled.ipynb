# %%
import pandas as pd

# %%
pd.read_parquet('/Users/xuechengliu/Downloads/cs229_project_report-main/code/data/databaseFrankfurtComplete.parquet')
# Out:
#             Close   Volume Ticker  Return_Delta1_VW  Return_Delta2_VW  \
# index
# 0       24.614100  26212.0  VOW.F          0.023688          0.000000
# 1       25.053894  17414.0  VOW.F          0.017868          0.023688
# 2       25.190874  16424.0  VOW.F          0.005467          0.017868
# 3       25.933481  42182.0  VOW.F          0.029479          0.005467
# 4       25.911858  24593.0  VOW.F         -0.000834          0.029479
# ...           ...      ...    ...               ...               ...
# 3804   169.682907     53.0  VOW.F         -0.012950         -0.001125
# 3805   169.440918    180.0  VOW.F         -0.001426         -0.012950
# 3806   168.279373     77.0  VOW.F         -0.006855         -0.001426
# 3807   168.811737    508.0  VOW.F          0.003164         -0.006855
# 3808   168.230972    150.0  VOW.F         -0.003440          0.003164
#
#        Return_Delta3_VW  Return_Delta4_VW  Return_Delta5_VW  Return_Delta6_VW  \
# index
# ...
